# %%
import pandas as pd 
import numpy as np

# %%
# load CsvAllfields.xlsx
df = pd.read_csv('./data/M250512 Budget Thuis Multi utility onderzoek MaxDiff_data_volledig_opgeschoond.csv')
df.head()
# Out:
#    sys_RespNum          d  MXD_1_b  MXD_1_w  MXD_2_b  MXD_2_w  MXD_3_b  \
# 0          748  411111358       16       26        3       12        2
# 1         1426  411111364       16        3        8        4       11
# 2          892  411111367        5       26       12       11       39
# 3         1482  411111369       10       26        6       24        9
# 4         1240  411111373        7       31       28       26        8
#
#    MXD_3_w  MXD_4_b  MXD_4_w  ...  nKOP5  nKOP6  nKOP7  nKOP8  nKOP9  nKOP10  \
# 0       19       21       28  ...      3      1    4.0      3    9.0       2
# 1       23       13       26  ...      8      1    NaN      3    5.0       2
# 2        3       40       27  ...      5      2    4.0      3    9.0       2
# 3        2        3       16  ...      8      1    4.0      2    3.0       2
# 4       34       20       18  ...      1      3    3.0      6    9.0       2
#
#    nKOP11  nKOP12  nKOP13   weegvar
# 0       2       1       1  0.882466
# ...

# %%
df.columns
# Out:
# Index(['sys_RespNum', 'd', 'MXD_1_b', 'MXD_1_w', 'MXD_2_b', 'MXD_2_w',
#        'MXD_3_b', 'MXD_3_w', 'MXD_4_b', 'MXD_4_w', 'MXD_5_b', 'MXD_5_w',
#        'MXD_6_b', 'MXD_6_w', 'MXD_7_b', 'MXD_7_w', 'MXD_8_b', 'MXD_8_w',
#        'MXD_9_b', 'MXD_9_w', 'MXD_10_b', 'MXD_10_w', 'MXD_11_b', 'MXD_11_w',
#        'MXD_12_b', 'MXD_12_w', 'MXD_13_b', 'MXD_13_w', 'MXD_14_b', 'MXD_14_w',
#        'MXD_15_b', 'MXD_15_w', 'MXD_16_b', 'MXD_16_w', 'MXD_17_b', 'MXD_17_w',
#        'MXD_18_b', 'MXD_18_w', 'sys_MXDDesignID_MXD', 'nKOP1', 'nKOP2',
#        'nKOP3', 'nKOP4', 'nKOP5', 'nKOP6', 'nKOP7', 'nKOP8', 'nKOP9', 'nKOP10',
#        'nKOP11', 'nKOP12', 'nKOP13', 'weegvar'],
#       dtype='object')

# %%
df = pd.read_excel('./data/M250512_MXD_Design.xlsx')
df.head()
# Out:
#    Version  Set  Item1  Item2  Item3  Item4  Item5
# 0        1    1     37     34      2     15     14
# 1        1    2     30      5     27     39     12
# 2        1    3     18     28     25     32      7
# 3        1    4     36      1     35     29     13
# 4        1    5     11     17      9     24      6

# %%
df.columns
# Out:
# Index(['Version', 'Set', 'Item1', 'Item2', 'Item3', 'Item4', 'Item5'], dtype='object')

# %%
df = pd.read_csv('data/Scores - MXD - Analysis run 1 - HB - 2025-Aug-11 - 1_03 PM - Probability scaled.csv')
df.head()
# Out:
#    Respondent ID       RLH  500 kWh gratis per jaar  \
# 0             17  0.250065                 0.561432
# 1             18  0.548544                 6.411792
# 2             19  0.575924                 7.410682
# 3             20  0.558523                 7.120400
# 4             21  0.626599                 1.146286
#
#    1.000 kWh gratis per jaar  1.500 kWh gratis per jaar  \
# 0                   0.505026                   0.588951
# 1                   7.228782                   7.304046
# 2                   8.008243                   8.031145
# 3                   7.562814                   7.625993
# 4                   2.928394                   4.458334
#
#    50 euro korting per jaar op je energierekening  \
# 0                                        2.546235
# 1                                        1.958357
# 2                                        2.089373
# 3                                        3.085720
# 4                                        5.837241
#
# ...

# %%
df.columns
# Out:
# Index(['Respondent ID', 'RLH', '500 kWh gratis per jaar',
#        '1.000 kWh gratis per jaar', '1.500 kWh gratis per jaar',
#        '50 euro korting per jaar op je energierekening',
#        '100 euro korting per jaar op je energierekening',
#        '150 euro korting per jaar op je energierekening',
#        '5% korting op het stroomtarief per jaar',
#        '10% korting op het stroomtarief per jaar',
#        '15% korting op het stroomtarief per jaar',
#        '20% korting op het stroomtarief per jaar',
#        '100 euro korting per jaar op energiebesparende producten',
#        '250 euro korting op Plug-In Thuisbatterij',
#        '500 euro korting op een Plug-In Thuisbatterij',
#        'Eenmalige cadeaukaart (zoals bijv. Bol.com of Coolblue) t.w.v. 100 euro',
#        'Eenmalige cadeaukaart (zoals bijv. Bol.com of Coolblue) t.w.v. 200 euro',
#        'Eenmalige cadeaukaart (zoals bijv. Bol.com of Coolblue) t.w.v. 300 euro',
# ...

# %%
# run_dataloader.py
from pathlib import Path
from data_loader import DataLoader  # make sure data_loader.py is in the same folder

def main():
    # --- paths (adjust to your file locations) ---
    responses_path = Path("./data/M250512 Budget Thuis Multi utility onderzoek MaxDiff_data_volledig_opgeschoond.csv")   # Dataset 1
    design_path = Path('./data/M250512_MXD_Design.xlsx')        # Dataset 2
    output_path = Path("maxdiff_compact.csv")

    # --- run pipeline ---
    dl = DataLoader()
    responses = dl.load_responses(responses_path)
    design = dl.load_design(design_path)
    compact = dl.combine(responses, design)
    dl.write_csv(compact, output_path)

    print("\nFirst rows of compact table:")
    print(compact.head())

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 22
#      19     print(compact.head())
#      21 if __name__ == "__main__":
# ---> 22     main()
#
# Cell In[29], line 13, in main()
#      11 # --- run pipeline ---
#      12 dl = DataLoader()
# ---> 13 responses = dl.load_responses(responses_path)
#      14 design = dl.load_design(design_path)
#      15 compact = dl.combine(responses, design)
#
# File c:\Users\PBR\OneDrive - Motivaction\Documents\Max_Diff_Hierarchical_Bayes\data_loader.py:23, in DataLoader.load_responses(self, filepath)
#      21 for col in required_cols:
#      22     if col not in df.columns:
# ---> 23         raise ValueError(f"Missing required column: {col}")
#      24 return df
#
# ValueError: Missing required column: sys_MXDVersion_MXD
